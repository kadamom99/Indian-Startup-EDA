# %%
#import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"E:\Data science\Datasets\Startups1.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Company       City  Starting Year  \
# 0           0  Urban Company    Gurgaon           2014
# 1           1      Classplus      Noida           2018
# 2           2          Paytm      Noida           2010
# 3           3           Apna     Mumbai           2019
# 4           4       Razorpay  Bengaluru           2014
#
#                                             Founders  \
# 0  Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 1  Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# 2                Akshay Khanna, Vijay Shekhar Sharma
# 3                                      Nirmit Parikh
# 4                     Harshil Mathur, Shashank Kumar
#
#                                           Industries  \
# 0  Apps, Home Services, Marketplace, Service Indu...
# 1  B2B, E-Learning, EdTech, Education, Mobile App...
# 2  E-Commerce, Finance, Financial Services, Inter...
# 3  Employment, Human Resources, Recruiting, Staff...
# ...

# %%
#Drop Unnamed Column
df.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
#Check Head
df.head()
# Out:
#          Company       City  Starting Year  \
# 0  Urban Company    Gurgaon           2014
# 1      Classplus      Noida           2018
# 2          Paytm      Noida           2010
# 3           Apna     Mumbai           2019
# 4       Razorpay  Bengaluru           2014
#
#                                             Founders  \
# 0  Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 1  Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# 2                Akshay Khanna, Vijay Shekhar Sharma
# 3                                      Nirmit Parikh
# 4                     Harshil Mathur, Shashank Kumar
#
#                                           Industries  \
# 0  Apps, Home Services, Marketplace, Service Indu...
# 1  B2B, E-Learning, EdTech, Education, Mobile App...
# 2  E-Commerce, Finance, Financial Services, Inter...
# 3  Employment, Human Resources, Recruiting, Staff...
# 4    Financial Services, FinTech, Payments, Software
#
# ...

# %%
#Check missing Values
df.isna().sum()
# Out:
# Company                0
# City                   0
# Starting Year          0
# Founders               0
# Industries             0
# Description            0
# No. of Employees       0
# Funding Amount in $    0
# Funding Round          0
# No. of Investors       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company              300 non-null    object
#  1   City                 300 non-null    object
#  2   Starting Year        300 non-null    int64
#  3   Founders             300 non-null    object
#  4   Industries           300 non-null    object
#  5   Description          300 non-null    object
#  6   No. of Employees     300 non-null    object
#  7   Funding Amount in $  300 non-null    int64
#  8   Funding Round        300 non-null    int64
#  9   No. of Investors     300 non-null    int64
# dtypes: int64(4), object(6)
# memory usage: 23.6+ KB

# %%
df['No. of Employees'].nunique()
# Out:
# 10

# %%
df['City'].unique()
# Out:
# array(['Gurgaon', 'Noida', 'Mumbai', 'Bengaluru', 'Kormangala',
#        'Hyderabad', 'New Delhi', 'Thane', 'Pune', 'Chennai', 'Andheri',
#        'Delhi', 'Patna City', 'Haryana', 'Faridabad', 'Ahmedabad',
#        'Surat', 'Kolkata', 'Sohna', 'Whitefield', 'Kilpauk', 'Azadpur',
#        'Nungambakkam', 'Jaipur'], dtype=object)

# %%
#HeatMap
corr=df.corr()
plt.figure(figsize=(5,5))
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#          Company       City  Starting Year  \
# 0  Urban Company    Gurgaon           2014
# 1      Classplus      Noida           2018
# 2          Paytm      Noida           2010
# 3           Apna     Mumbai           2019
# 4       Razorpay  Bengaluru           2014
#
#                                             Founders  \
# 0  Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 1  Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# 2                Akshay Khanna, Vijay Shekhar Sharma
# 3                                      Nirmit Parikh
# 4                     Harshil Mathur, Shashank Kumar
#
#                                           Industries  \
# 0  Apps, Home Services, Marketplace, Service Indu...
# 1  B2B, E-Learning, EdTech, Education, Mobile App...
# 2  E-Commerce, Finance, Financial Services, Inter...
# 3  Employment, Human Resources, Recruiting, Staff...
# 4    Financial Services, FinTech, Payments, Software
#
# ...

# %%
plt.figure(figsize=(15,5))
df.groupby('Starting Year')['Company'].count().plot.bar()
plt.ylabel("No of companies")
# Out:
# Text(0, 0.5, 'No of companies')

# %% [markdown]
# # There was a spike in growth of number of startups in 2015

# %%
df[df['Starting Year']==2015].sort_values(by=['Funding Amount in $'], ascending=False)
# Out:
#        Company       City  Starting Year  \
# 244  ShareChat  Bengaluru           2015
# 72   PharmEasy     Mumbai           2015
# 291     Meesho  Bengaluru           2015
# 10   Unacademy  Bengaluru           2015
# 28      CARS24    Gurgaon           2015
# ..         ...        ...            ...
# 252  WorkIndia     Mumbai           2015
# 268       Niki  Bengaluru           2015
# 296   Pariksha       Pune           2015
# 282  MCaffeine     Mumbai           2015
# 118    FarMart    Gurgaon           2015
#
#                                               Founders  \
# 244   Ankush Sachdeva, Bhanu Pratap Singh, Farid Ahsan
# 72           Dharmil Sheth, Dhaval Shah, Mikhil Innani
# 291                      Sanjeev Barnwal, Vidit Aatrey
# 10   Gaurav Munjal, Hemesh Singh, Roman Saini, Sach...
# 28   Gajendra Jangid, Mehul Agrawal, Ruchit Agarwal...
# ..                                                 ...
# 252  Ajay Kumar, Jatin Jakharia, Kshitij Nagvekar, ...
# ...

# %%
years=df['Starting Year'].unique()
years=np.sort(years)

# %%
years
# Out:
# array([1984, 1989, 1990, 1991, 1995, 1996, 1998, 1999, 2000, 2001, 2004,
#        2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#        2017, 2018, 2019, 2020], dtype=int64)

# %%
df['Starting Year'].nunique()
# Out:
# 26

# %% [markdown]
# # Top10 companies with hightest funding rounds

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='Funding Round',y='Company',data=df.sort_values('Funding Round', ascending=False).iloc[:10],alpha=0.8)  
plt.title('Companies with highest funding rounds',fontsize=20)    #Note labelling the data
plt.ylabel('Company',fontsize=20)               #Note labelling the y-label
plt.xlabel('Count',fontsize=20)               #Note labelling the x-label
plt.tick_params(labelsize=8)
plt.show()

# %% [markdown]
# # Top10 companies with highest Funding Amount in $

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='Funding Amount in $',y='Company',data=df.sort_values('Funding Amount in $', ascending=False).iloc[:10],alpha=0.8)  
plt.title('Companies with highest funding ',fontsize=20)    #Note labelling the data
plt.ylabel('Company',fontsize=20)               #Note labelling the y-label
plt.xlabel('Funding Amount in $',fontsize=20)               #Note labelling the x-label
plt.tick_params(labelsize=8)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='No. of Investors',y='Company',data=df.sort_values('No. of Investors', ascending=False).iloc[:10],alpha=0.8)  
plt.title('Companies with highest No. of Investors',fontsize=20)    #Note labelling the data
plt.ylabel('Company',fontsize=20)               #Note labelling the y-label
plt.xlabel('No. of Investors',fontsize=20)               #Note labelling the x-label
plt.tick_params(labelsize=8)
plt.show()

# %% [markdown]
# # Lets see the top 10 companies in each year receiving more funds

# %%
fig, axes = plt.subplots(13, 2, sharex=True, figsize=(16,50))
fig.tight_layout(pad=10)
for n in years:
    i=1+ int(np.where(years==n)[0])
    plt.subplot(13,2,i, title=n)
    sns.barplot(y='Company', x='Funding Amount in $', data=df[df['Starting Year']==n].sort_values('Funding Amount in $', ascending=False).iloc[:10])
    plt.xticks(rotation=0)

# %%
plt.figure(figsize=(15,5))
df.groupby('Starting Year')['Funding Amount in $'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Starting Year'>

# %% [markdown]
# ### More funds were recieved in the year 2010

# %% [markdown]
# ## Lets check which companies recieved more or contributed more

# %%
df[df['Starting Year']==2010].sort_values(by=['Funding Amount in $'], ascending=False)
# Out:
#           Company        City  Starting Year  \
# 32   Reliance Jio      Mumbai           2010
# 11            Ola  Kormangala           2010
# 51       Snapdeal     Gurgaon           2010
# 271    Paytm Mall       Noida           2010
# 292      Lenskart   Faridabad           2010
# 209    FreeCharge      Mumbai           2010
# 270     Neogrowth      Mumbai           2010
# 161       Netmeds     Chennai           2010
# 170    Chai Point   Bengaluru           2010
# 195        CropIn   Bengaluru           2010
# 2           Paytm       Noida           2010
# 75         Upstox      Mumbai           2010
#
#                                 Founders  \
# 32                         Mukesh Ambani
# 11         Ankit Bhati, Bhavish Aggarwal
# 51              Kunal Bahl, Rohit Bansal
# 271                 Vijay Shekhar Sharma
# 292        Amit Chaudhary, Peyush Bansal
# 209           Kunal Shah, Sandeep Tandon
# 270        Dhruv Khaitan, Piyush Khaitan
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Company', y='Funding Amount in $', data=df[df['Starting Year']==2010])
# Out:
# <AxesSubplot:xlabel='Company', ylabel='Funding Amount in $'>

# %%
df['No. of Employees'].unique()
# Out:
# array(['1001-5000', '101-250', '501-1000', '5001-10000', '11-50',
#        '251-500', '10001+', '51-100', '1-10', 'Not Available'],
#       dtype=object)

# %%
df.groupby('No. of Employees')['Company'].count().sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='No. of Employees'>

# %%
plt.figure(figsize=(10,7))
df.groupby('City')['Company'].count().sort_values(ascending=False).plot.bar()
plt.show()

# %%
df[df.City=='Bengaluru']
# Out:
#                    Company       City  Starting Year  \
# 4                 Razorpay  Bengaluru           2014
# 8                BigBasket  Bengaluru           2011
# 10               Unacademy  Bengaluru           2015
# 12                 Licious  Bengaluru           2015
# 13                    CRED  Bengaluru           2018
# ..                     ...        ...            ...
# 291                 Meesho  Bengaluru           2015
# 293                  Udaan  Bengaluru           2016
# 294                  Zolve  Bengaluru           2020
# 297                  Fyllo  Bengaluru           2019
# 299  HalaPlay Technologies  Bengaluru           2016
#
#                                               Founders  \
# 4                       Harshil Mathur, Shashank Kumar
# 8    Abhinay Choudhari, Hari Menon, Vipul Parekh, V...
# 10   Gaurav Munjal, Hemesh Singh, Roman Saini, Sach...
# 12                          Abhay Hanjura, Vivek Gupta
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### From above study we can observe that Bengaluru has More Companies
